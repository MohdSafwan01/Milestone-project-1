# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdSafwan01/Milestone-project-1/blob/main/Displaying_Information.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print([1,2,3])
# Out:
# [1, 2, 3]

# %%
row_1=[' ',' ',' ']
row_2=[' ',' ',' ']
row_3=[' ',' ',' ']

# %%
def display(row_1,row_2,row_3):
  print(row_1)
  print(row_2)
  print(row_3)

# %%
display(row_1,row_2,row_3)
# Out:
# [' ', ' ', ' ']
# [' ', 'X', ' ']
# [' ', ' ', ' ']

# %%
row_2[1]='X'
